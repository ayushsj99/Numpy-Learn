# %%
import numpy as np

mylist = [2,3,5,6,8,9]

# %%
mylist #Normal list
# Out:
# [2, 3, 5, 6, 8, 9]

# %%
myarray = np.array(mylist) #synt of defining a numpy array

# %%
myarray #This is a numpy array
# Out:
# array([2, 3, 5, 6, 8, 9])

# %%
type(myarray)
# Out:
# numpy.ndarray
